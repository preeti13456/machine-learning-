# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('nyc_taxi_trip_duration.csv')

# %%
df
# Out:
#                id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0       id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1       id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2       id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3       id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4       id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
# ...           ...        ...                  ...                  ...
# 729317  id3905982          2  2016-05-21 13:29:38  2016-05-21 13:34:34
# 729318  id0102861          1  2016-02-22 00:43:11  2016-02-22 00:48:26
# 729319  id0439699          1  2016-04-15 18:56:48  2016-04-15 19:08:01
# 729320  id2078912          1  2016-06-19 09:50:47  2016-06-19 09:58:14
# 729321  id1053441          2  2016-01-01 17:24:16  2016-01-01 17:44:40
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.771164                  N            400
# ...

# %%
df.dropna()
# Out:
#                id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0       id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1       id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2       id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3       id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4       id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
# ...           ...        ...                  ...                  ...
# 729317  id3905982          2  2016-05-21 13:29:38  2016-05-21 13:34:34
# 729318  id0102861          1  2016-02-22 00:43:11  2016-02-22 00:48:26
# 729319  id0439699          1  2016-04-15 18:56:48  2016-04-15 19:08:01
# 729320  id2078912          1  2016-06-19 09:50:47  2016-06-19 09:58:14
# 729321  id1053441          2  2016-01-01 17:24:16  2016-01-01 17:44:40
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %%
df.iloc[1:]
# Out:
#                id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1       id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2       id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3       id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4       id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
# 5       id1918069          2  2016-02-14 18:31:42  2016-02-14 18:55:57
# ...           ...        ...                  ...                  ...
# 729317  id3905982          2  2016-05-21 13:29:38  2016-05-21 13:34:34
# 729318  id0102861          1  2016-02-22 00:43:11  2016-02-22 00:48:26
# 729319  id0439699          1  2016-04-15 18:56:48  2016-04-15 19:08:01
# 729320  id2078912          1  2016-06-19 09:50:47  2016-06-19 09:58:14
# 729321  id1053441          2  2016-01-01 17:24:16  2016-01-01 17:44:40
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
df.shape
# Out:
# (729322, 11)

# %%
df.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %%
df[:]
# Out:
#                id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0       id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1       id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2       id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3       id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4       id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
# ...           ...        ...                  ...                  ...
# 729317  id3905982          2  2016-05-21 13:29:38  2016-05-21 13:34:34
# 729318  id0102861          1  2016-02-22 00:43:11  2016-02-22 00:48:26
# 729319  id0439699          1  2016-04-15 18:56:48  2016-04-15 19:08:01
# 729320  id2078912          1  2016-06-19 09:50:47  2016-06-19 09:58:14
# 729321  id1053441          2  2016-01-01 17:24:16  2016-01-01 17:44:40
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
df.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# ...

# %%
target = df['trip_duration']

# %%
ax = sns.catplot(y="trip_duration", kind="count", data=df, height=2.6, aspect=2.5, orient='v')

# %%
print(df.columns.dtype)
# Out:
# object

# %%
df['trip_duration'].value_counts(normalize=True)
# Out:
# 348      0.001138
# 363      0.001108
# 368      0.001108
# 388      0.001104
# 358      0.001094
#            ...
# 5049     0.000001
# 84882    0.000001
# 4370     0.000001
# 4226     0.000001
# 6262     0.000001
# Name: trip_duration, Length: 6296, dtype: float64

# %%
df.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %%
numerical_cols = ['vendor_id','passenger_count','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','trip_duration']
df[numerical_cols].describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# ...

# %%
df.corr()
# Out:
#                    vendor_id  passenger_count  pickup_longitude  \
# vendor_id           1.000000         0.286463          0.008198
# passenger_count     0.286463         1.000000          0.001163
# pickup_longitude    0.008198         0.001163          1.000000
# pickup_latitude     0.002861        -0.004696          0.047635
# dropoff_longitude   0.002371        -0.000027          0.780647
# dropoff_latitude    0.005259        -0.003944          0.118473
# trip_duration       0.027752         0.013022          0.035447
#
#                    pickup_latitude  dropoff_longitude  dropoff_latitude  \
# vendor_id                 0.002861           0.002371          0.005259
# passenger_count          -0.004696          -0.000027         -0.003944
# pickup_longitude          0.047635           0.780647          0.118473
# pickup_latitude           1.000000           0.119970          0.479352
# dropoff_longitude         0.119970           1.000000          0.149598
# ...

# %%
df.groupby('pickup_latitude')['pickup_longitude'].mean()
# Out:
# pickup_latitude
# 34.712234    -75.354332
# 35.310307    -72.074333
# 37.389381   -121.933342
# 37.777771    -77.896019
# 38.898849    -77.039436
#                 ...
# 42.458942    -70.511902
# 43.139652    -72.591019
# 43.486885    -74.195145
# 43.911762    -71.881645
# 51.881084    -72.809669
# Name: pickup_longitude, Length: 39776, dtype: float64

# %%
df.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# ...

# %%
df.groupby('passenger_count')['vendor_id'].mean()
# Out:
# passenger_count
# 0    1.424242
# 1    1.467961
# 2    1.562347
# 3    1.618045
# 4    1.576157
# 5    1.995530
# 6    1.997055
# 7    2.000000
# 9    2.000000
# Name: vendor_id, dtype: float64

# %%
df.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# ...

# %%
cols = ['vendor_id','passenger_count','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','trip_duration']
df.groupby(['trip_duration'])[cols].mean()
df[numerical_cols].describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# ...

# %%
temp = np.log(df['pickup_latitude'] + 90 )
sns.distplot(temp, kde = False, bins=10)
plt.show()

# %%
sns.distplot(df['pickup_longitude'], kde = False)
plt.show()

# %%
t = np.log(df['pickup_longitude']+70)
sns.distplot(t, kde=False, bins=10)
plt.show()
# Out:
# C:\Users\preeti sharma\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
temp = np.log(df['dropoff_longitude']+100)
sns.distplot(temp, kde=False, bins=12)
plt.show()
# Out:
# C:\Users\preeti sharma\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
temp = np.log(df['dropoff_latitude']+5)
sns.distplot(temp, kde=False, bins=15)
plt.show()

# %%
# Numerical Features
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 6))
xmin = 7
xmax = 16
# Current Month Average Balance
temp = np.log(df['pickup_longitude'] + 100) # To account for negative values we add a constant value within log
ax1.set_xlim([xmin,xmax])
ax1.set(xlabel='log of average pickup longitude in current month')
sns.distplot(temp, kde = False, bins = 1, ax = ax1)


# Previous month average balance
temp = np.log(df['dropoff_longitude'] + 100) # To account for negative values we add a constant value within log
ax2.set_xlim([xmin,xmax])
ax2.set(xlabel='log of average dropoff longitude in previous month')
sns.distplot(temp, kde = False, bins = 5, ax = ax2)


plt.show()
# Out:
# C:\Users\preeti sharma\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\preeti sharma\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Numerical Features
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 6))
xmin = 7
xmax = 16
# Current Month Average Balance
temp = np.log(df['pickup_latitude'] + 6000) # To account for negative values we add a constant value within log
ax1.set_xlim([xmin,xmax])
#ax1.set(xlabel='log of average balance of current month')
sns.distplot(temp, kde = False, bins = 200, ax = ax1)


# Current End of month average balance
temp = np.log(df['dropoff_latitude'] + 6000) # To account for negative values we add a constant value within log
ax2.set_xlim([xmin,xmax])
#ax2.set(xlabel='log of month end balance of current  month')
sns.distplot(temp, kde = False, bins = 200, ax = ax2)


plt.show()

# %%
pickup_cols = ['pickup_longitude','pickup_latitude','dropoff_latitude','dropoff_longitude']
df1 = pd.DataFrame()
for i in pickup_cols:
    df1[str('log_')+ i] = np.log(df[i] + 6000)

log_pickup_cols = df1.columns

# %%
df1['trip_duration'] = df['trip_duration']

# %%
df1_no_trip = df1[df1['trip_duration'] == 0]
sns.pairplot(df1_no_trip,vars=log_pickup_cols,plot_kws={'alpha':0.1})
plt.show()

# %%
df1_trip = df1[df1['trip_duration'] == 1]
sns.pairplot(df1_trip, vars=log_pickup_cols, plot_kws= {'alpha' : 0.1} )
plt.show()

# %%
df['dropoff_longitude'].corr(df['dropoff_latitude'])
# Out:
# 0.14959785415314344

# %%
df['dropoff_latitude'].corr(df['dropoff_longitude'])
# Out:
# 0.14959785415314347

# %%
df['pickup_longitude'].corr(df['dropoff_longitude'])
# Out:
# 0.780646586323788

# %%
df['pickup_longitude'].corr(df['pickup_longitude'])
# Out:
# 1.0

# %%
t_cols = ['pickup_longitude','pickup_latitude', 
              'dropoff_longitude', 'dropoff_latitude']
df1 = pd.DataFrame()

for i in t_cols:
    df1[str('log_')+ i] = np.log(df[i])

log_t_cols = df1.columns
# Out:
# C:\Users\preeti sharma\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df1['trip_duration'] = df['trip_duration']

# %%
#Tabular Representation of Continous Contionus Bivariate Analysis
df.groupby('pickup_longitude')['dropoff_latitude'].mean().plot.bar()

# %%
df.groupby('pickup_longitude')['dropoff_longitude'].mean().plot.bar()

# %%
sns.pairplot(df1, vars=log_pickup_cols, plot_kws={'alpha' : 0.1})
plt.show()

# %%
sns.pairplot(df1, vars=log_t_cols, hue = 'trip_duration', plot_kws={'alpha' : 0.5})
plt.show()
# Out:
# C:\Users\preeti sharma\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\preeti sharma\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\preeti sharma\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\preeti sharma\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\preeti sharma\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
b_cols = ['pickup_longitude', 'dropoff_longitude']
df1 = pd.DataFrame()

for i in b_cols:
    df1[str('log_')+ i] = np.log(df[i] + 17000)

log_b_cols = df1.columns
df1['trip_duration'] = df['trip_duration']

# %%
sns.pairplot(df1,vars=log_b_cols, hue = 'trip_duration',plot_kws={'alpha':0.5})
plt.show()

# %%
d_cols = ['pickup_latitude', 'dropoff_latitude']
df1 = pd.DataFrame()

for i in d_cols:
    df1[str('log_')+ i] = np.log(df[i] + 17000)

log_d_cols = df1.columns
df1['trip_duration'] = df['trip_duration']

# %%
sns.pairplot(df1, vars = log_d_cols, plot_kws = {'alpha' : 1})
plt.show()

# %%
c_cols = ['pickup_longitude', 'pickup_latitude']
df1 = pd.DataFrame()

for i in c_cols:
    df1[str('log_')+ i] = np.log(df[i] + 17000)

log_c_cols = df1.columns
df1['trip_duration'] = df['trip_duration']

# %%
sns.pairplot(df1, vars = log_c_cols, plot_kws = {'alpha' : 1})
plt.show()

# %%
e_cols = ['dropoff_longitude', 'dropoff_latitude']
df1 = pd.DataFrame()

for i in e_cols:
    df1[str('log_')+ i] = np.log(df[i] + 17000)

log_e_cols = df1.columns
df1['trip_duration'] = df['trip_duration']

# %%
sns.pairplot(df1, vars = log_e_cols, plot_kws = {'alpha' : 1})
plt.show()

# %%
# Remove 1st and 99th percentile and plot

df2 = df[['pickup_latitude', 'dropoff_latitude']]

low = .01
high = .99
quant_df = df2.quantile([low, high])
print(quant_df)

# %%
df2 = df[['pickup_latitude', 'dropoff_longitude']]

low = .01
high = .99
quant_df = df2.quantile([low, high])
print(quant_df)

# %%
df3 = df2.apply(lambda x :  x[(x>quant_df.loc[low,x.name]) & 
                                    (x < quant_df.loc[high,x.name])], axis=0)

# %%
q_cols = ['pickup_longitude', 'pickup_latitude']
df1 = pd.DataFrame()

for i in q_cols:
    df1[str('log_')+ i] = np.log(df[i] + 17000)

log_q_cols = df1.columns
df1['trip_duration'] = df['trip_duration']

# %%
sns.pairplot(df1, vars = log_q_cols, hue = 'trip_duration',plot_kws = {'alpha' : 0.5})
plt.show()

# %%
sns.pairplot(df1, vars = log_q_cols, hue = 'trip_duration',plot_kws = {'alpha' : 0.2})
plt.show()

# %%
# KDE Plot Smoothens out even if there are no values for a value
def kdeplot(feature):
    plt.figure(figsize=(9, 4))
    plt.title("KDE Plot for {}".format(feature))
    ax0 = sns.kdeplot(df[df['trip_duration'] == 0][feature].dropna(), color= 'dodgerblue', label= 'Trip - 0')
    ax1 = sns.kdeplot(df[df['trip_duration'] == 1][feature].dropna(), color= 'orange', label= 'Trip - 1')

kdeplot('passenger_count')

# %%
kdeplot('vendor_id')

# %%
df = df[df['trip_duration']<300]

# %%
df['passenger_count'].value_counts().head(20)

# %%
df['vendor_id'].value_counts().head(20)

# %%
df['pickup'] = df['pickup_latitude'].copy()
counts = df.pickup_latitude.value_counts()
df.pickup[df['pickup_latitude'].isin(counts[counts > 900].index)] = 3
df.pickup[df['pickup_latitude'].isin(counts[counts < 900].index) & df['pickup'].isin(counts[counts >= 350].index)] = 2
df.pickup[df['pickup_latitude'].isin(counts[counts < 350].index) & df['pickup'].isin(counts[counts >= 100].index)] = 1
df.pickup[df['pickup_latitude'].isin(counts[counts < 100].index)] = 0

df['pickup'] = pd.to_numeric(df['pickup'], errors='coerce')

# %%
df['pickup_longitude'].value_counts()

# %%
int_level = df['pickup_longitude'].value_counts()

plt.figure(figsize=(8,4))
sns.barplot(int_level.index,  alpha=0.8, color=color[1])
plt.ylabel('Duration of trip', fontsize=12)
plt.xlabel('branch bins', fontsize=12)
plt.show()

# %%
def barplot_percentages(feature):
    #fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 6))
    ax1 = df.groupby(feature)['trip_duration'].value_counts(normalize=True).unstack()
    ax1.plot(kind='bar', stacked='True')
    int_level = df[feature].value_counts()

    plt.figure(figsize=(8,4))
    sns.barplot(int_level.index, int_level.values, alpha=0.8, color=color[1])
    plt.ylabel('Duration of trip', fontsize=12)
    plt.xlabel(str(feature), fontsize=12)
    plt.show()

# %%
df['pickup_longitude'][df['pickup_longitude'] > 3] = 3

# %%
bins=[0,0.5,6]
group = ['Var','Car']
df['pickup_latitude'] = pd.cut(df['trip_duration'],bins,labels=group)

# %%
df.head()

# %%
sorted_data = df.sort_values(by='trip_duration')

# %%
sorted_data[:5]

# %%
df.isnull().issum()
